# %% [markdown]
# # Extract, Transform, and Load dataset from CSV to PostgreSQL using Python pandas SQL library
# ## Part 2 : Use join in python dataframe

# %% [markdown]
# ## Library Preparation

# %%
# Import Library needed
import pandas as pd
from pandasql import sqldf
from sqlalchemy import create_engine

# %% [markdown]
# ## Database Configuration

# %%
# Postgresql database configuration
db_uri = 'postgresql+psycopg2://postgres:A321654z@localhost:5432/mydb'

# create engine for dataframe connection to postgresql
engine = create_engine(db_uri)

# %% [markdown]
# ## Extract Dataset from Parquet and CSV dataset (read dataset)

# %%
# Extract dataset parquet
df_parquet = pd.read_parquet('C:\\Users\\ffatahillah\\Documents\\Data Engineer\\de_basic_class_etl-main\\dataset\\green_tripdata_2019-01.parquet')
df_parquet
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1              2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2              2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3              2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4              2  2019-01-01 00:19:06   2019-01-01 00:39:43
# ...          ...                  ...                   ...
# 672100         2  2019-01-31 23:08:00   2019-01-31 23:28:00
# 672101         2  2019-01-31 23:28:00   2019-01-31 23:47:00
# 672102         2  2019-01-31 23:14:00   2019-01-31 23:29:00
# 672103         2  2019-01-31 23:41:00   2019-01-31 23:48:00
# 672104         2  2019-01-31 23:16:00   2019-01-31 23:39:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           264           264
# 1                       N         1.0            97            49
# 2                       N         1.0            49           189
# 3                       N         1.0           189            17
# 4                       N         1.0            82           258
# ...                   ...         ...           ...           ...
# 672100               None         NaN            25           177
# 672101               None         NaN            85           256
# 672102               None         NaN           168           182
# 672103               None         NaN            72            72
# 672104               None         NaN            51           235
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 0                   5.0           0.00         3.00   0.50      0.5
# 1                   2.0           0.86         6.00   0.50      0.5
# 2                   2.0           0.66         4.50   0.50      0.5
# 3                   2.0           2.68        13.50   0.50      0.5
# 4                   1.0           4.53        18.00   0.50      0.5
# ...                 ...            ...          ...    ...      ...
# 672100              NaN           4.26        23.00   5.50      0.5
# 672101              NaN           5.21        28.95   2.75      0.5
# 672102              NaN           5.45        29.25   2.75      0.5
# 672103              NaN           0.35        48.65   2.75      0.5
# 672104              NaN           7.16        48.65   2.75      0.5
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 0             0.00           0.0        NaN                    0.3
# 1             0.00           0.0        NaN                    0.3
# 2             0.00           0.0        NaN                    0.3
# 3             2.96           0.0        NaN                    0.3
# 4             0.00           0.0        NaN                    0.3
# ...            ...           ...        ...                    ...
# 672100        0.00           0.0        NaN                    0.0
# 672101        0.00           0.0        NaN                    0.3
# 672102        0.00           0.0        NaN                    0.0
# 672103        0.00           0.0        NaN                    0.0
# 672104        0.00           0.0        NaN                    0.0
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 0               4.30           2.0        1.0                   NaN
# 1               7.30           2.0        1.0                   NaN
# 2               5.80           1.0        1.0                   NaN
# 3              19.71           1.0        1.0                   NaN
# 4              19.30           2.0        1.0                   NaN
# ...              ...           ...        ...                   ...
# 672100         29.00           NaN        NaN                   NaN
# 672101         32.50           NaN        NaN                   NaN
# 672102         32.50           NaN        NaN                   NaN
# 672103         51.90           NaN        NaN                   NaN
# 672104         51.90           NaN        NaN                   NaN
#
# [672105 rows x 20 columns]

# %%
# Extract dataset Csv
df_csv = pd.read_csv('C:\\Users\\ffatahillah\\Documents\\Data Engineer\\de_basic_class_etl-main\\dataset\\taxi+_zone_lookup.csv')
df_csv
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %% [markdown]
# ## Transform : Use Panda SQL to Query the dataset with SQL query format
# ### step 1: Select specific columns in table df_parquet

# %%
df_parquet_table = sqldf(''' Select VendorID,
                          lpep_pickup_datetime,
                          lpep_dropoff_datetime,
                          RatecodeID,
                          PULocationID,
                          DOLocationID,
                          passenger_count,
                          trip_distance,
                          total_amount,
                          payment_type,
                          trip_type
                          FROM df_parquet
                          ''')

#Check the data
df_parquet_table
# Out:
#         VendorID        lpep_pickup_datetime       lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29.000000  2018-12-21 15:18:57.000000
# 1              2  2019-01-01 00:10:16.000000  2019-01-01 00:16:32.000000
# 2              2  2019-01-01 00:27:11.000000  2019-01-01 00:31:38.000000
# 3              2  2019-01-01 00:46:20.000000  2019-01-01 01:04:54.000000
# 4              2  2019-01-01 00:19:06.000000  2019-01-01 00:39:43.000000
# ...          ...                         ...                         ...
# 672100         2  2019-01-31 23:08:00.000000  2019-01-31 23:28:00.000000
# 672101         2  2019-01-31 23:28:00.000000  2019-01-31 23:47:00.000000
# 672102         2  2019-01-31 23:14:00.000000  2019-01-31 23:29:00.000000
# 672103         2  2019-01-31 23:41:00.000000  2019-01-31 23:48:00.000000
# 672104         2  2019-01-31 23:16:00.000000  2019-01-31 23:39:00.000000
#
#         RatecodeID  PULocationID  DOLocationID  passenger_count  \
# 0              1.0           264           264              5.0
# 1              1.0            97            49              2.0
# 2              1.0            49           189              2.0
# 3              1.0           189            17              2.0
# 4              1.0            82           258              1.0
# ...            ...           ...           ...              ...
# 672100         NaN            25           177              NaN
# 672101         NaN            85           256              NaN
# 672102         NaN           168           182              NaN
# 672103         NaN            72            72              NaN
# 672104         NaN            51           235              NaN
#
#         trip_distance  total_amount  payment_type  trip_type
# 0                0.00          4.30           2.0        1.0
# 1                0.86          7.30           2.0        1.0
# 2                0.66          5.80           1.0        1.0
# 3                2.68         19.71           1.0        1.0
# 4                4.53         19.30           2.0        1.0
# ...               ...           ...           ...        ...
# 672100           4.26         29.00           NaN        NaN
# 672101           5.21         32.50           NaN        NaN
# 672102           5.45         32.50           NaN        NaN
# 672103           0.35         51.90           NaN        NaN
# 672104           7.16         51.90           NaN        NaN
#
# [672105 rows x 11 columns]

# %% [markdown]
# ### Step 2 : Join the table above with csv dataset

# %%
df_join_table = sqldf(''' Select dft.*, dc.Borough, dc.Zone,dc.service_zone
from df_parquet_table dft inner join df_csv dc on dft.PULocationID = dc.LocationID ''')

# Check the join data
df_join_table
# Out:
#         VendorID        lpep_pickup_datetime       lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29.000000  2018-12-21 15:18:57.000000
# 1              2  2019-01-01 00:10:16.000000  2019-01-01 00:16:32.000000
# 2              2  2019-01-01 00:27:11.000000  2019-01-01 00:31:38.000000
# 3              2  2019-01-01 00:46:20.000000  2019-01-01 01:04:54.000000
# 4              2  2019-01-01 00:19:06.000000  2019-01-01 00:39:43.000000
# ...          ...                         ...                         ...
# 672100         2  2019-01-31 23:08:00.000000  2019-01-31 23:28:00.000000
# 672101         2  2019-01-31 23:28:00.000000  2019-01-31 23:47:00.000000
# 672102         2  2019-01-31 23:14:00.000000  2019-01-31 23:29:00.000000
# 672103         2  2019-01-31 23:41:00.000000  2019-01-31 23:48:00.000000
# 672104         2  2019-01-31 23:16:00.000000  2019-01-31 23:39:00.000000
#
#         RatecodeID  PULocationID  DOLocationID  passenger_count  \
# 0              1.0           264           264              5.0
# 1              1.0            97            49              2.0
# 2              1.0            49           189              2.0
# 3              1.0           189            17              2.0
# 4              1.0            82           258              1.0
# ...            ...           ...           ...              ...
# 672100         NaN            25           177              NaN
# 672101         NaN            85           256              NaN
# 672102         NaN           168           182              NaN
# 672103         NaN            72            72              NaN
# 672104         NaN            51           235              NaN
#
#         trip_distance  total_amount  payment_type  trip_type   Borough  \
# 0                0.00          4.30           2.0        1.0   Unknown
# 1                0.86          7.30           2.0        1.0  Brooklyn
# 2                0.66          5.80           1.0        1.0  Brooklyn
# 3                2.68         19.71           1.0        1.0  Brooklyn
# 4                4.53         19.30           2.0        1.0    Queens
# ...               ...           ...           ...        ...       ...
# 672100           4.26         29.00           NaN        NaN  Brooklyn
# 672101           5.21         32.50           NaN        NaN  Brooklyn
# 672102           5.45         32.50           NaN        NaN     Bronx
# 672103           0.35         51.90           NaN        NaN  Brooklyn
# 672104           7.16         51.90           NaN        NaN     Bronx
#
#                                 Zone service_zone
# 0                                 NV         None
# 1                        Fort Greene    Boro Zone
# 2                       Clinton Hill    Boro Zone
# 3                   Prospect Heights    Boro Zone
# 4                           Elmhurst    Boro Zone
# ...                              ...          ...
# 672100                   Boerum Hill    Boro Zone
# 672101                       Erasmus    Boro Zone
# 672102        Mott Haven/Port Morris    Boro Zone
# 672103  East Flatbush/Remsen Village    Boro Zone
# 672104                    Co-Op City    Boro Zone
#
# [672105 rows x 14 columns]

# %%
# Show unique value from service zone columns
df_join_table['service_zone'].unique()
# Out:
# array([None, 'Boro Zone', 'Yellow Zone', 'Airports', 'EWR'], dtype=object)

# %%
# filter the join data where service zone is Airports
df_airports = sqldf(''' Select * from df_join_table where service_zone = 'Airports'  ''')

#Check the data
df_airports
# Out:
#      VendorID        lpep_pickup_datetime       lpep_dropoff_datetime  \
# 0           2  2019-01-01 04:21:50.000000  2019-01-01 04:23:13.000000
# 1           2  2019-01-01 06:34:52.000000  2019-01-01 06:35:00.000000
# 2           2  2019-01-01 11:34:31.000000  2019-01-01 11:36:20.000000
# 3           2  2019-01-01 20:28:38.000000  2019-01-01 20:28:39.000000
# 4           2  2019-01-02 13:47:42.000000  2019-01-02 13:47:44.000000
# ..        ...                         ...                         ...
# 123         2  2019-01-08 10:50:00.000000  2019-01-08 10:50:00.000000
# 124         2  2019-01-13 05:44:00.000000  2019-01-13 05:44:00.000000
# 125         2  2019-01-19 15:59:00.000000  2019-01-19 16:09:00.000000
# 126         2  2019-01-20 07:12:00.000000  2019-01-20 07:12:00.000000
# 127         2  2019-01-21 10:29:00.000000  2019-01-21 10:48:00.000000
#
#      RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           5.0           138           138              1.0           0.00
# 1           5.0           132           132              1.0           0.03
# 2           5.0           138           138              2.0           0.00
# 3           5.0           132           132              2.0           0.00
# 4           5.0           132           132              1.0           0.23
# ..          ...           ...           ...              ...            ...
# 123         NaN           138           138              NaN           0.00
# 124         NaN           132           132              NaN           0.00
# 125         NaN           138           226              NaN           4.12
# 126         NaN           138           138              NaN           0.05
# 127         NaN           138           162              NaN           5.93
#
#      total_amount  payment_type  trip_type Borough               Zone  \
# 0           14.40           1.0        2.0  Queens  LaGuardia Airport
# 1           66.00           1.0        2.0  Queens        JFK Airport
# 2           40.33           1.0        2.0  Queens  LaGuardia Airport
# 3           49.20           1.0        2.0  Queens        JFK Airport
# 4           15.00           1.0        2.0  Queens        JFK Airport
# ..            ...           ...        ...     ...                ...
# 123          0.00           NaN        NaN  Queens  LaGuardia Airport
# 124         43.00           NaN        NaN  Queens        JFK Airport
# 125         39.50           NaN        NaN  Queens  LaGuardia Airport
# 126          0.00           NaN        NaN  Queens  LaGuardia Airport
# 127         65.40           NaN        NaN  Queens  LaGuardia Airport
#
#     service_zone
# 0       Airports
# 1       Airports
# 2       Airports
# 3       Airports
# 4       Airports
# ..           ...
# 123     Airports
# 124     Airports
# 125     Airports
# 126     Airports
# 127     Airports
#
# [128 rows x 14 columns]

# %% [markdown]
# ## Load to PostgreSQL

# %%
# Count the data
count_df = df_airports.shape[0]
count_df
# Out:
# 128

# %%
# Defined table nama
table_name = service_zone_airports

#Load to PostgreSQL with specific configuration
df_airports.to_sql(name=table_name,con=engine,index=False,if_exists='append')
print(f'Total Record have been inserted are {count_df} to table {table_name} ')
